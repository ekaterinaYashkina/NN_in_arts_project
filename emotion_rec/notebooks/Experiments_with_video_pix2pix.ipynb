# %%
# !git clone -b video https://github.com/jctestud/pix2pixHD.git
# Out:
# Cloning into 'pix2pixHD'...
# remote: Enumerating objects: 409, done.
# remote: Total 409 (delta 0), reused 0 (delta 0), pack-reused 409
# Receiving objects: 100% (409/409), 55.70 MiB | 12.32 MiB/s, done.
# Resolving deltas: 100% (202/202), done.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# Loading the nets from gdrive

# %%
# !unzip "drive/My Drive/snow_files/checkpoints_l.zip"
# Out:
# Archive:  drive/My Drive/snow_files/checkpoints_l.zip
#   inflating: checkpoints/sunrise_project/latest_net_G.pth
#   inflating: checkpoints/sunrise_project/latest_net_D.pth
#   inflating: checkpoints/sunrise_project/loss_log.txt
#   inflating: checkpoints/sunrise_project/opt.txt
#  extracting: checkpoints/sunrise_project/iter.txt

# %%
# !unzip "drive/My Drive/snow_files/datasets.zip"
# Out:
# Archive:  drive/My Drive/snow_files/datasets.zip
#    creating: datasets-2/
#   inflating: __MACOSX/._datasets-2
#   inflating: datasets-2/.DS_Store
#   inflating: __MACOSX/datasets-2/._.DS_Store
#    creating: datasets-2/citymotion_dataset/
#   inflating: __MACOSX/datasets-2/._citymotion_dataset
#    creating: datasets-2/cityscapes/
#   inflating: __MACOSX/datasets-2/._cityscapes
#    creating: datasets-2/citymotion_dataset/test_frames/
#   inflating: __MACOSX/datasets-2/citymotion_dataset/._test_frames
#    creating: datasets-2/citymotion_dataset/train_frames/
#   inflating: __MACOSX/datasets-2/citymotion_dataset/._train_frames
#    creating: datasets-2/cityscapes/train_img/
#   inflating: __MACOSX/datasets-2/cityscapes/._train_img
#    creating: datasets-2/cityscapes/test_label/
#   inflating: __MACOSX/datasets-2/cityscapes/._test_label
#    creating: datasets-2/cityscapes/test_inst/
#   inflating: __MACOSX/datasets-2/cityscapes/._test_inst
# ...

# %%
import os

# %%
# !pip3 install dominate

# %%
# !rm -r pix2pixHD

# %%
# !cp -a pix2pixHD/. ./

# %%
# !cp -a custom_data/ ./

# %%
# !cp -a pix2pixHD/data/. ./data/
# !cp -a pix2pixHD/datasets/. ./datasets/
# !cp -a pix2pixHD/imgs/. ./imgs/
# !cp -a pix2pixHD/models/. ./models/
# !cp -a pix2pixHD/options/. ./options/
# !cp -a pix2pixHD/scripts/. ./scripts/
# !cp -a pix2pixHD/util/. ./util/

# %%
# !python3 extract_frames.py -video snow.mp4 -name snow_dataset -p2pdir . -width 1280 -height 736
# Out:
# creating the dataset structure
# ffmpeg -v 16 -i /content/snow.mp4 -q:v 2 -vf "scale=iw*736/ih:736, crop=1280:736" /content/datasets/snow_dataset/train_frames/frame-%06d.jpg -hide_banner
# extracting the frames

# %% [markdown]
# Then there is just a long pipeline of training/video generation. Each cell trains only one epoch - it is just a trick, so colab will not take away the GPU for a couple of days because of long cell run

# %%
# !python3 train_video.py --name sunrise_project --dataroot ./datasets/sunrise_dataset/ --save_epoch_freq 1 --ngf 32
# Out:
# ------------ Options -------------
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: False
# data_type: 32
# dataroot: ./datasets/sunrise_dataset/
# debug: False
# display_freq: 100
# display_winsize: 512
# feat_num: 3
# fineSize: 512
# fps: 24.0
# gpu_ids: [0]
# heat_seeking_lvl: 0
# input_nc: 3
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 35
# lambda_feat: 10.0
# loadSize: 1024
# load_features: False
# load_pretrain:
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: sunrise_project
# ndf: 64
# nef: 16
# netG: global
# ngf: 32
# niter: 100
# niter_decay: 100
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# output_nc: 3
# phase: train
# ...

# %%
epoch+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d37aa196733b> in <module>()
# ----> 1 epoch+=1
#
# NameError: name 'epoch' is not defined

# %%
# !zip -r 'drive/My Drive/snow_files/checkpoints.zip' checkpoints
# Out:
#   adding: checkpoints/ (stored 0%)
#   adding: checkpoints/citymotion_project/ (stored 0%)
#   adding: checkpoints/citymotion_project/2_net_D.pth (deflated 7%)
#   adding: checkpoints/citymotion_project/latest_net_G.pth (deflated 7%)
#   adding: checkpoints/citymotion_project/1_net_D.pth (deflated 7%)
#   adding: checkpoints/citymotion_project/3_net_G.pth (deflated 7%)
#   adding: checkpoints/citymotion_project/iter.txt (stored 0%)
#   adding: checkpoints/citymotion_project/2_net_G.pth (deflated 7%)
#   adding: checkpoints/citymotion_project/latest_net_D.pth (deflated 7%)
#   adding: checkpoints/citymotion_project/1_net_G.pth (deflated 7%)
#   adding: checkpoints/citymotion_project/3_net_D.pth (deflated 7%)
#   adding: checkpoints/citymotion_project/opt.txt (deflated 51%)
#   adding: checkpoints/citymotion_project/web/ (stored 0%)
#   adding: checkpoints/citymotion_project/web/images/ (stored 0%)
#   adding: checkpoints/citymotion_project/loss_log.txt (deflated 74%)

# %%
# !zip -r 'drive/My Drive/snow_files/datasets.zip' datasets
# Out:
#   adding: datasets/ (stored 0%)
#   adding: datasets/cityscapes/ (stored 0%)
#   adding: datasets/cityscapes/test_inst/ (stored 0%)
#   adding: datasets/cityscapes/test_inst/frankfurt_000001_054640_gtFine_instanceIds.png (deflated 6%)
#   adding: datasets/cityscapes/test_inst/frankfurt_000001_013710_gtFine_instanceIds.png (deflated 8%)
#   adding: datasets/cityscapes/test_inst/frankfurt_000001_028335_gtFine_instanceIds.png (deflated 6%)
#   adding: datasets/cityscapes/test_inst/frankfurt_000000_003357_gtFine_instanceIds.png (deflated 11%)
#   adding: datasets/cityscapes/test_inst/frankfurt_000001_015328_gtFine_instanceIds.png (deflated 10%)
#   adding: datasets/cityscapes/test_inst/frankfurt_000001_032711_gtFine_instanceIds.png (deflated 13%)
#   adding: datasets/cityscapes/test_inst/frankfurt_000001_033655_gtFine_instanceIds.png (deflated 13%)
#   adding: datasets/cityscapes/test_inst/frankfurt_000000_011810_gtFine_instanceIds.png (deflated 6%)
# ...

# %%
# !zip -r 'drive/My Drive/snow_files/checkpoints_l.zip' checkpoints/sunrise_project/latest_net_G.pth checkpoints/sunrise_project/latest_net_D.pth checkpoints/sunrise_project/loss_log.txt checkpoints/sunrise_project/opt.txt checkpoints/sunrise_project/iter.txt
# Out:
#   adding: checkpoints/sunrise_project/latest_net_G.pth (deflated 7%)
#   adding: checkpoints/sunrise_project/latest_net_D.pth (deflated 7%)
#   adding: checkpoints/sunrise_project/loss_log.txt (deflated 71%)
#   adding: checkpoints/sunrise_project/opt.txt (deflated 50%)
#   adding: checkpoints/sunrise_project/iter.txt (stored 0%)

# %%
# !python3 train_video.py --name sunrise_project --dataroot ./datasets/sunrise_dataset/ --continue_train --save_epoch_freq 1 --ngf 32
# Out:
# ------------ Options -------------
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: True
# data_type: 32
# dataroot: ./datasets/sunrise_dataset/
# debug: False
# display_freq: 100
# display_winsize: 512
# feat_num: 3
# fineSize: 512
# fps: 24.0
# gpu_ids: [0]
# heat_seeking_lvl: 0
# input_nc: 3
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 35
# lambda_feat: 10.0
# loadSize: 1024
# load_features: False
# load_pretrain:
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: sunrise_project
# ndf: 64
# nef: 16
# netG: global
# ngf: 32
# niter: 100
# niter_decay: 100
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# output_nc: 3
# phase: train
# ...

# %%
# !zip -r 'drive/My Drive/snow_files/checkpoints_l.zip' checkpoints/sunrise_project/latest_net_G.pth checkpoints/sunrise_project/latest_net_D.pth checkpoints/sunrise_project/loss_log.txt checkpoints/sunrise_project/opt.txt checkpoints/sunrise_project/iter.txt
# Out:
# updating: checkpoints/sunrise_project/latest_net_G.pth (deflated 7%)
# updating: checkpoints/sunrise_project/latest_net_D.pth (deflated 7%)
# updating: checkpoints/sunrise_project/loss_log.txt (deflated 82%)
# updating: checkpoints/sunrise_project/opt.txt (deflated 50%)
# updating: checkpoints/sunrise_project/iter.txt (stored 0%)

# %%
epoch = 0

# %%
epoch+=1

# %%
# !python3 train_video.py --name sunrise_project --dataroot ./datasets/sunrise_dataset/ --continue_train --save_epoch_freq 1 --ngf 32
# Out:
# ------------ Options -------------
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: True
# data_type: 32
# dataroot: ./datasets/sunrise_dataset/
# debug: False
# display_freq: 100
# display_winsize: 512
# feat_num: 3
# fineSize: 512
# fps: 24.0
# gpu_ids: [0]
# heat_seeking_lvl: 0
# input_nc: 3
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 35
# lambda_feat: 10.0
# loadSize: 1024
# load_features: False
# load_pretrain:
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: sunrise_project
# ndf: 64
# nef: 16
# netG: global
# ngf: 32
# niter: 100
# niter_decay: 100
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# output_nc: 3
# phase: train
# ...

# %%
# !zip -r 'drive/My Drive/snow_files/checkpoints_l.zip' checkpoints/sunrise_project/latest_net_G.pth checkpoints/sunrise_project/latest_net_D.pth checkpoints/sunrise_project/loss_log.txt checkpoints/sunrise_project/opt.txt checkpoints/sunrise_project/iter.txt
# Out:
# updating: checkpoints/sunrise_project/latest_net_G.pth
#
#
# zip error: Interrupted (aborting)

# %%
epoch+=1

# %%
# !python3 train_video.py --name sunrise_project --dataroot ./datasets/sunrise_dataset/ --continue_train --save_epoch_freq 1 --ngf 32
# Out:
# ------------ Options -------------
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: True
# data_type: 32
# dataroot: ./datasets/sunrise_dataset/
# debug: False
# display_freq: 100
# display_winsize: 512
# feat_num: 3
# fineSize: 512
# fps: 24.0
# gpu_ids: [0]
# heat_seeking_lvl: 0
# input_nc: 3
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 35
# lambda_feat: 10.0
# loadSize: 1024
# load_features: False
# load_pretrain:
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: sunrise_project
# ndf: 64
# nef: 16
# netG: global
# ngf: 32
# niter: 100
# niter_decay: 100
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# output_nc: 3
# phase: train
# ...

# %%
epoch+=1

# %%
# !zip -r 'drive/My Drive/snow_files/checkpoints_l.zip' checkpoints/sunrise_project/latest_net_G.pth checkpoints/sunrise_project/latest_net_D.pth checkpoints/sunrise_project/loss_log.txt checkpoints/sunrise_project/opt.txt checkpoints/sunrise_project/iter.txt
# Out:
# updating: checkpoints/sunrise_project/latest_net_G.pth
#
#
# zip error: Interrupted (aborting)

# %%
# !python3 train_video.py --name sunrise_project --dataroot ./datasets/sunrise_dataset/ --continue_train --save_epoch_freq 1 --ngf 32
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-607d8241e9f9> in <module>()
# ----> 1 get_ipython().system('python3 train_video.py --name sunrise_project --dataroot ./datasets/sunrise_dataset/ --continue_train --save_epoch_freq 1 --ngf 32')
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_shell.py in system(self, *args, **kwargs)
#      94       kwargs.update({'also_return_output': True})
#      95
# ---> 96     output = _system_commands._system_compat(self, *args, **kwargs)  # pylint:disable=protected-access
#      97
#      98     if pip_warn:
#
# /usr/local/lib/python3.6/dist-packages/google/colab/_system_commands.py in _system_compat(shell, cmd, also_return_output)
#     436   # stack.
#     437   result = _run_command(
# --> 438       shell.var_expand(cmd, depth=2), clear_streamed_output=False)
# ...

# %%
# !zip -r 'drive/My Drive/snow_files/checkpoints_l.zip' checkpoints/sunrise_project/latest_net_G.pth checkpoints/sunrise_project/latest_net_D.pth checkpoints/sunrise_project/loss_log.txt checkpoints/sunrise_project/opt.txt checkpoints/sunrise_project/iter.txt

# %%
# !python3 train_video.py --name sunrise_project --dataroot ./datasets/sunrise_dataset/ --continue_train --save_epoch_freq 1 --ngf 32

# %%
# !!zip -r 'drive/My Drive/snow_files/checkpoints_l.zip' checkpoints/sunrise_project/latest_net_G.pth checkpoints/sunrise_project/latest_net_D.pth checkpoints/sunrise_project/loss_log.txt checkpoints/sunrise_project/opt.txt checkpoints/sunrise_project/iter.txt

# %%
# !python3 train_video.py --name sunrise_project --dataroot ./datasets/sunrise_dataset/ --continue_train --save_epoch_freq 1 --ngf 32

# %%
# !zip -r 'drive/My Drive/snow_files/checkpoints_l.zip' checkpoints/sunrise_project/latest_net_G.pth checkpoints/sunrise_project/latest_net_D.pth checkpoints/sunrise_project/loss_log.txt checkpoints/sunrise_project/opt.txt checkpoints/sunrise_project/iter.txt

# %%
# !zip -r 'drive/My Drive/snow_files/checkpoints.zip' checkpoints

# %%
# !python3 train_video.py --name sunrise_project --dataroot ./datasets/sunrise_dataset/ --continue_train --save_epoch_freq 1 --ngf 32

# %%
# !zip -r 'drive/My Drive/snow_files/checkpoints_l.zip' checkpoints/sunrise_project/latest_net_G.pth checkpoints/sunrise_project/latest_net_D.pth checkpoints/sunrise_project/loss_log.txt checkpoints/sunrise_project/opt.txt checkpoints/sunrise_project/iter.txt

# %%
epoch+=1

# %%
# !zip -r 'drive/My Drive/snow_files/datasets_{}.zip'.format(epoch) datasets
# !zip -r 'drive/My Drive/snow_files/checkpoints.zip' checkpoints

# %%
# !python3 train_video.py --name snow_project --dataroot ./datasets/snow_dataset/ --continue_train --save_epoch_freq 1 --ngf 32
# Out:
# ------------ Options -------------
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: True
# data_type: 32
# dataroot: ./datasets/snow_dataset/
# debug: False
# display_freq: 100
# display_winsize: 512
# feat_num: 3
# fineSize: 512
# fps: 24.0
# gpu_ids: [0]
# heat_seeking_lvl: 0
# input_nc: 3
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 35
# lambda_feat: 10.0
# loadSize: 1024
# load_features: False
# load_pretrain:
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: snow_project
# ndf: 64
# nef: 16
# netG: global
# ngf: 32
# niter: 100
# niter_decay: 100
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# output_nc: 3
# phase: train
# pool_size: 0
# ...

# %%
epoch+=1

# %%
# !zip -r 'drive/My Drive/snow_files/checkpoints.zip' checkpoints
# Out:
# updating: checkpoints/ (stored 0%)
# updating: checkpoints/fireball_project/ (stored 0%)
# updating: checkpoints/fireball_project/2_net_D.pth (deflated 7%)
# updating: checkpoints/fireball_project/5_net_D.pth (deflated 7%)
# updating: checkpoints/fireball_project/4_net_D.pth (deflated 7%)
# updating: checkpoints/fireball_project/latest_net_G.pth (deflated 7%)
# updating: checkpoints/fireball_project/6_net_D.pth (deflated 7%)
# updating: checkpoints/fireball_project/1_net_D.pth (deflated 7%)
# updating: checkpoints/fireball_project/7_net_D.pth (deflated 7%)
# updating: checkpoints/fireball_project/7_net_G.pth (deflated 7%)
# updating: checkpoints/fireball_project/loss_log.txt (deflated 80%)
# updating: checkpoints/fireball_project/latest_net_D.pth (deflated 7%)
# updating: checkpoints/fireball_project/opt.txt (deflated 50%)
# updating: checkpoints/fireball_project/1_net_G.pth (deflated 7%)
# updating: checkpoints/fireball_project/4_net_G.pth (deflated 7%)
# ...

# %%
# !python3 train_video.py --name snow_project --dataroot ./datasets/snow_dataset/ --continue_train --save_epoch_freq 1 --ngf 32
# Out:
# ------------ Options -------------
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: True
# data_type: 32
# dataroot: ./datasets/snow_dataset/
# debug: False
# display_freq: 100
# display_winsize: 512
# feat_num: 3
# fineSize: 512
# fps: 24.0
# gpu_ids: [0]
# heat_seeking_lvl: 0
# input_nc: 3
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 35
# lambda_feat: 10.0
# loadSize: 1024
# load_features: False
# load_pretrain:
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: snow_project
# ndf: 64
# nef: 16
# netG: global
# ngf: 32
# niter: 100
# niter_decay: 100
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# output_nc: 3
# phase: train
# pool_size: 0
# ...

# %%
epoch+=1

# %%
# !zip -r 'drive/My Drive/snow_files/checkpoints.zip' checkpoints
# Out:
# updating: checkpoints/ (stored 0%)
# updating: checkpoints/snow_project/ (stored 0%)
# updating: checkpoints/snow_project/5_net_D.pth (deflated 7%)
# updating: checkpoints/snow_project/3_net_D.pth (deflated 7%)
# updating: checkpoints/snow_project/6_net_D.pth (deflated 7%)
# updating: checkpoints/snow_project/5_net_G.pth (deflated 7%)
# updating: checkpoints/snow_project/4_net_G.pth (deflated 7%)
# updating: checkpoints/snow_project/1_net_D.pth (deflated 7%)
# updating: checkpoints/snow_project/4_net_D.pth (deflated 7%)
# updating: checkpoints/snow_project/iter.txt (stored 0%)
# updating: checkpoints/snow_project/6_net_G.pth (deflated 7%)
# updating: checkpoints/snow_project/latest_net_D.pth (deflated 7%)
# updating: checkpoints/snow_project/web/ (stored 0%)
# updating: checkpoints/snow_project/web/images/ (stored 0%)
# updating: checkpoints/snow_project/opt.txt (deflated 50%)
# updating: checkpoints/snow_project/loss_log.txt (deflated 81%)
# ...

# %%
# !python3 train_video.py --name snow_project --dataroot ./datasets/snow_dataset/ --continue_train --save_epoch_freq 1 --ngf 32
# Out:
# ------------ Options -------------
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: True
# data_type: 32
# dataroot: ./datasets/snow_dataset/
# debug: False
# display_freq: 100
# display_winsize: 512
# feat_num: 3
# fineSize: 512
# fps: 24.0
# gpu_ids: [0]
# heat_seeking_lvl: 0
# input_nc: 3
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 35
# lambda_feat: 10.0
# loadSize: 1024
# load_features: False
# load_pretrain:
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: snow_project
# ndf: 64
# nef: 16
# netG: global
# ngf: 32
# niter: 100
# niter_decay: 100
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# output_nc: 3
# phase: train
# pool_size: 0
# ...

# %%
epoch+=1

# %%
# !zip -r 'drive/My Drive/snow_files/checkpoints.zip' checkpoints
# Out:
# updating: checkpoints/ (stored 0%)
# updating: checkpoints/snow_project/ (stored 0%)
# updating: checkpoints/snow_project/5_net_D.pth (deflated 7%)
# updating: checkpoints/snow_project/3_net_D.pth (deflated 7%)
# updating: checkpoints/snow_project/6_net_D.pth (deflated 7%)
# updating: checkpoints/snow_project/5_net_G.pth (deflated 7%)
# updating: checkpoints/snow_project/4_net_G.pth (deflated 7%)
# updating: checkpoints/snow_project/1_net_D.pth (deflated 7%)
# updating: checkpoints/snow_project/4_net_D.pth (deflated 7%)
# updating: checkpoints/snow_project/iter.txt (stored 0%)
# updating: checkpoints/snow_project/6_net_G.pth (deflated 7%)
# updating: checkpoints/snow_project/latest_net_D.pth (deflated 7%)
# updating: checkpoints/snow_project/web/ (stored 0%)
# updating: checkpoints/snow_project/web/images/ (stored 0%)
# updating: checkpoints/snow_project/opt.txt (deflated 50%)
# updating: checkpoints/snow_project/loss_log.txt (deflated 81%)
# ...

# %%
# !python3 train_video.py --name snow_project --dataroot ./datasets/snow_dataset/ --continue_train --save_epoch_freq 1 --ngf 32
# Out:
# ------------ Options -------------
# batchSize: 1
# beta1: 0.5
# checkpoints_dir: ./checkpoints
# continue_train: True
# data_type: 32
# dataroot: ./datasets/snow_dataset/
# debug: False
# display_freq: 100
# display_winsize: 512
# feat_num: 3
# fineSize: 512
# fps: 24.0
# gpu_ids: [0]
# heat_seeking_lvl: 0
# input_nc: 3
# instance_feat: False
# isTrain: True
# label_feat: False
# label_nc: 35
# lambda_feat: 10.0
# loadSize: 1024
# load_features: False
# load_pretrain:
# lr: 0.0002
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_layers_D: 3
# n_local_enhancers: 1
# name: snow_project
# ndf: 64
# nef: 16
# netG: global
# ngf: 32
# niter: 100
# niter_decay: 100
# niter_fix_global: 0
# no_flip: False
# no_ganFeat_loss: False
# no_html: False
# no_instance: False
# no_lsgan: False
# no_vgg_loss: False
# norm: instance
# num_D: 2
# output_nc: 3
# phase: train
# pool_size: 0
# ...

# %%
epoch+=1

# %%
# !zip -r 'drive/My Drive/snow_files/checkpoints.zip' checkpoints
# Out:
# updating: checkpoints/ (stored 0%)
# updating: checkpoints/snow_project/ (stored 0%)
# updating: checkpoints/snow_project/5_net_D.pth (deflated 7%)
# updating: checkpoints/snow_project/3_net_D.pth (deflated 7%)
# updating: checkpoints/snow_project/6_net_D.pth (deflated 7%)
# updating: checkpoints/snow_project/5_net_G.pth
#
#
# zip error: Interrupted (aborting)

# %%
# !ls -R ./checkpoints
# Out:
# ./checkpoints:
# snow_project
#
# ./checkpoints/snow_project:
# 1_net_D.pth  3_net_D.pth  5_net_D.pth  iter.txt		 opt.txt
# 1_net_G.pth  3_net_G.pth  5_net_G.pth  latest_net_D.pth  web
# 2_net_D.pth  4_net_D.pth  6_net_D.pth  latest_net_G.pth
# 2_net_G.pth  4_net_G.pth  6_net_G.pth  loss_log.txt
#
# ./checkpoints/snow_project/web:
# images
#
# ./checkpoints/snow_project/web/images:

# %%
# !mkdir /usr/share/fonts/truetype/ubuntu

# %%
# !cp Ubuntu-B.ttf /usr/share/fonts/truetype/ubuntu/

# %%
# !python3 generate_video.py --name snow_project --dataroot ./datasets/snow_dataset/ --fps 24 --ngf 32 --how_many 400
# Out:
# ------------ Options -------------
# aspect_ratio: 1.0
# batchSize: 1
# checkpoints_dir: ./checkpoints
# cluster_path: features_clustered_010.npy
# data_type: 32
# dataroot: ./datasets/snow_dataset/
# display_winsize: 512
# engine: None
# export_onnx: None
# feat_num: 3
# fineSize: 512
# fps: 24.0
# gpu_ids: [0]
# heat_seeking_lvl: 0
# how_many: 400
# input_nc: 3
# instance_feat: False
# isTrain: False
# label_feat: False
# label_nc: 35
# loadSize: 1024
# load_features: False
# max_dataset_size: inf
# model: pix2pixHD
# nThreads: 2
# n_blocks_global: 9
# n_blocks_local: 3
# n_clusters: 10
# n_downsample_E: 4
# n_downsample_global: 4
# n_local_enhancers: 1
# name: snow_project
# nef: 16
# netG: global
# ngf: 32
# niter_fix_global: 0
# no_flip: False
# no_instance: False
# norm: instance
# ntest: inf
# onnx: None
# output_nc: 3
# phase: test
# pstart: 1
# pstop: 1
# resize_or_crop: scale_width
# results_dir: ./results/
# scheduled_sampling: False
# serial_batches: False
# ...

# %%
# !zip -r frames_ытщц.zip ./checkpoints/snow_project/frames
# Out:
#   adding: checkpoints/snow_project/frames/ (stored 0%)
#   adding: checkpoints/snow_project/frames/frame-00306.jpg (deflated 6%)
#   adding: checkpoints/snow_project/frames/frame-00298.jpg (deflated 6%)
#   adding: checkpoints/snow_project/frames/frame-00273.jpg (deflated 6%)
#   adding: checkpoints/snow_project/frames/frame-00260.jpg (deflated 6%)
#   adding: checkpoints/snow_project/frames/frame-00007.jpg (deflated 3%)
#   adding: checkpoints/snow_project/frames/frame-00388.jpg (deflated 6%)
#   adding: checkpoints/snow_project/frames/frame-00332.jpg (deflated 6%)
#   adding: checkpoints/snow_project/frames/frame-00339.jpg (deflated 6%)
#   adding: checkpoints/snow_project/frames/frame-00086.jpg (deflated 6%)
#   adding: checkpoints/snow_project/frames/frame-00164.jpg (deflated 6%)
#   adding: checkpoints/snow_project/frames/frame-00074.jpg (deflated 5%)
#   adding: checkpoints/snow_project/frames/frame-00139.jpg (deflated 6%)
# ...

# %%
from google.colab import files
files.download('./checkpoints/citymotion_project/output/epoch-latest_citymotion_project_16.7-s_24.0-fps.mp4')

# %%
os.listdir("./checkpoints/sunrise_project/frames")
# Out:
# ['frame-00337.jpg',
#  'frame-00277.jpg',
#  'frame-00046.jpg',
#  'frame-00078.jpg',
#  'frame-00071.jpg',
#  'frame-00441.jpg',
#  'frame-00167.jpg',
#  'frame-00151.jpg',
#  'frame-00338.jpg',
#  'frame-00222.jpg',
#  'frame-00261.jpg',
#  'frame-00154.jpg',
#  'frame-00198.jpg',
#  'frame-00432.jpg',
#  'frame-00287.jpg',
#  'frame-00252.jpg',
#  'frame-00244.jpg',
#  'frame-00237.jpg',
#  'frame-00065.jpg',
#  'frame-00250.jpg',
#  'frame-00067.jpg',
#  'frame-00259.jpg',
#  'frame-00062.jpg',
#  'frame-00045.jpg',
#  'frame-00325.jpg',
#  'frame-00447.jpg',
#  'frame-00184.jpg',
#  'frame-00072.jpg',
#  'frame-00102.jpg',
#  'frame-00276.jpg',
#  'frame-00169.jpg',
#  'frame-00173.jpg',
#  'frame-00207.jpg',
#  'frame-00162.jpg',
#  'frame-00272.jpg',
#  'frame-00021.jpg',
#  'frame-00033.jpg',
#  'frame-00311.jpg',
#  'frame-00183.jpg',
#  'frame-00423.jpg',
#  'frame-00314.jpg',
#  'frame-00243.jpg',
#  'frame-00251.jpg',
#  'frame-00357.jpg',
#  'frame-00239.jpg',
# ...

# %%
# !zip -r frames_sunrise.zip checkpoints
# Out:
# updating: checkpoints/sunrise_project/frames/ (stored 0%)
# updating: checkpoints/ (stored 0%)
#   adding: checkpoints/sunrise_project/ (stored 0%)
#   adding: checkpoints/sunrise_project/latest_net_G.pth (deflated 7%)
#   adding: checkpoints/sunrise_project/output/ (stored 0%)
#   adding: checkpoints/sunrise_project/output/epoch-latest_sunrise_project_16.7-s_24.0-fps.mp4 (deflated 0%)
#   adding: checkpoints/sunrise_project/latest_net_D.pth (deflated 7%)
#   adding: checkpoints/sunrise_project/loss_log.txt (deflated 82%)
#   adding: checkpoints/sunrise_project/iter.txt (stored 0%)
#   adding: checkpoints/sunrise_project/opt.txt (deflated 50%)
#   adding: checkpoints/sunrise_project/frames/frame-00337.jpg (deflated 3%)
#   adding: checkpoints/sunrise_project/frames/frame-00277.jpg (deflated 3%)
#   adding: checkpoints/sunrise_project/frames/frame-00046.jpg (deflated 3%)
#   adding: checkpoints/sunrise_project/frames/frame-00078.jpg (deflated 3%)
# ...

# %%
from google.colab import files
files.download('checkpoints/sunrise_project/frames/frame-00357.jpg')

# %%
# !zip -r checkoints_9D.zip ./checkpoints/cloud_project/9_net_D.pth
# Out:
#   adding: checkpoints/cloud_project/9_net_D.pth (deflated 7%)

# %%
# !ls -R ./checkpoints

# %%
# !fc-list
# Out:
# /usr/share/fonts/truetype/liberation/LiberationSansNarrow-Italic.ttf: Liberation Sans Narrow:style=Italic
# /usr/share/fonts/truetype/liberation/LiberationSans-Regular.ttf: Liberation Sans:style=Regular
# /usr/share/fonts/truetype/liberation/LiberationMono-BoldItalic.ttf: Liberation Mono:style=Bold Italic
# /usr/share/fonts/truetype/liberation/LiberationSerif-Italic.ttf: Liberation Serif:style=Italic
# /usr/share/fonts/truetype/liberation/LiberationMono-Bold.ttf: Liberation Mono:style=Bold
# /usr/share/fonts/opentype/font-awesome/FontAwesome.otf: FontAwesome:style=Regular
# /usr/share/fonts/truetype/liberation/LiberationSansNarrow-Regular.ttf: Liberation Sans Narrow:style=Regular
# /usr/share/fonts/truetype/liberation/LiberationSerif-Bold.ttf: Liberation Serif:style=Bold
# /usr/share/fonts/truetype/liberation/LiberationMono-Regular.ttf: Liberation Mono:style=Regular
# /usr/share/fonts/truetype/ubuntu/Ubuntu-B.ttf: Ubuntu:style=Bold
# ...
